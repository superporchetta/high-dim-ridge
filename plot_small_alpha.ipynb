# %%
import numpy as np
import pylab as plt
import seaborn as sns
from scipy import optimize
import matplotlib
import pickle
from numerics import find_coefficients_Huber, find_coefficients_L2
import time
from sklearn.linear_model import HuberRegressor

# %%
plt.figure(figsize=(5.5,2.5))
for i in range(10):
    d = np.loadtxt("./comp_{:d}_cv_MSE_lambda_sweep_a_opt_alpha_0.03.csv".format(i), delimiter=",", skiprows=1)
    d2 = np.loadtxt("./upper_comp_{:d}_cv_MSE_lambda_sweep_a_opt_alpha_0.03.csv".format(i), delimiter=",", skiprows=1)
    color = next(plt.gca()._get_lines.prop_cycler)['color']
    plt.plot(d[:,0], d[:,1], color = color)
    plt.plot(d2[:,0], d2[:,1], color = color)

plt.title(r"$\alpha$ = 0.03")
plt.xlabel(r"$\lambda$")
plt.ylabel("Cross Validated MSE")
plt.xscale('log')
# plt.ylim(0, 1.5)
plt.show()

# %%
plt.figure(figsize=(5.5,2.5))
for i in range(10):
    d = np.loadtxt("./comp_{:d}_cv_MSE_lambda_sweep_a_opt_alpha_0.03.csv".format(i), delimiter=",", skiprows=1)
    d2 = np.loadtxt("./upper_comp_{:d}_cv_MSE_lambda_sweep_a_opt_alpha_0.03.csv".format(i), delimiter=",", skiprows=1)
    color = next(plt.gca()._get_lines.prop_cycler)['color']
    plt.plot(d[:,0], d[:,2], color = color)
    plt.plot(d2[:,0], d2[:,2], color = color)

plt.title(r"$\alpha$ = 0.03")
plt.xlabel(r"$\lambda$")
plt.ylabel(r"$a_{opt}$")
plt.xscale('log')
# plt.ylim(0, 1.5)
plt.show()
